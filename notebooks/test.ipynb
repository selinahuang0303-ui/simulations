# %%
import sys

sys.path.append("../src")

# %%
from generate_predictors import generate_predictors

GLOBAL_CONFIG = {
    "n": 500,
    "random_state": 42
}

X1_CONFIG = {
    "dimension": 5,
    "variable_type": "continuous",
    "distribution": "normal",
    "distribution_params": {

        "mean": 0,

        "std": 1

    }
}

X2_CONFIG = {
    "dimension": 500,
    "variable_type": "continuous",
    "distribution": "gamma",
    "distribution_params": {

        "mean": 2,

        "std": 5

    }
}

X1 = generate_predictors(GLOBAL_CONFIG, X1_CONFIG)
X2 = generate_predictors(GLOBAL_CONFIG, X2_CONFIG)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 35
#      21 X2_CONFIG = {
#      22     "dimension": 500,
#      23     "variable_type": "continuous",
#    (...)
#      31     }
#      32 }
#      34 X1 = generate_predictors(GLOBAL_CONFIG, X1_CONFIG)
# ---> 35 X2 = generate_predictors(GLOBAL_CONFIG, X2_CONFIG)
#
# File c:\Users\selin\Documents\simulations\notebooks\../src\generate_predictors.py:38, in generate_predictors(global_config, local_config)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# ValueError: Unsupported variable type

# %%
print(X1.shape)
# Out:
# (500, 5)
